# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import random
import math

# Selecting 40% of Training set for actual training.
df = pd.read_csv("train.csv")
# n = int(max(df.count()))
# s = int(n * .4)
# skip = sorted(random.sample(range(1, n+1), n-s))
# df = pd.read_csv("train.csv", skiprows=skip)


#Features
#--------
#has_name
#animaltype
#gender
#isNeutered/spayed
#ageuponoutcome (in years)
#isShihTzu
#isAggressive (Rottweiler, PitBull, Siberian Husky)
#isMix
#Dog groups (break this up in a bit)
#Cat groups (Shorthair, Medium hair, Long hair, other)
#    be careful to split everything accordingly. Inconsistencies with entries.
#ismulticolour

# Prints all cat breeds with count
#df = df['Breed'].where(df['AnimalType'] == 'Cat').dropna()
#df = df.value_counts()

def hasName(x):
    if isinstance(x, str):
        return 1
    return 0
    
def intact(x):
    x = x.lower()
    if x == "unknown":
        return 0
    if ("spayed" in x or "neutered" in x):
        return 1
    return 2

def gender(x):
    if "Male" in x:
        return 1
    if "Female" in x:
        return 2
    return 0

def convertAge(x):
    

def prepare_features(df):
    df['SexuponOutcome'].fillna('Unknown', inplace=True)
    df['AgeuponOutcome'].fillna("-1 months", inplace=True)
    
    df['hasName'] = df['Name'].apply(lambda x: hasName(x))
    
    df['intact'] = df['SexuponOutcome'].apply(lambda x: intact(x))
    df['gender'] = df['SexuponOutcome'].apply(lambda x: gender(x))
    df['age'] = df['AgeuponOutcome'].apply(lambda x: convertAge(x))
    
    
    df.drop(['AnimalID', 
             'DateTime', 
             'OutcomeType', 
             'SexuponOutcome',
             'Name'], axis=1, inplace=True)

#prepare_features(df)
#print(df)

print(df['AgeuponOutcome'].value_counts())
print(df['AgeuponOutcome'].count())
# Out:
# 1 year       3969
# 2 years      3742
# 2 months     3397
# 3 years      1823
# 1 month      1281
# 3 months     1277
# 4 years      1071
# 5 years       992
# 4 months      888
# 6 years       670
# 3 weeks       659
# 5 months      652
# 6 months      588
# 8 years       536
# 7 years       531
# 2 weeks       529
# 10 months     457
# 10 years      446
# 8 months      402
# 4 weeks       334
# 7 months      288
# 9 years       288
# 12 years      234
# 9 months      224
# 1 weeks       171
# 11 months     166
# 1 week        146
# 13 years      143
# 11 years      126
# 3 days        109
# 2 days         99
# 14 years       97
# 15 years       85
# 1 day          66
# 4 days         50
# 6 days         50
# 16 years       36
# 5 days         24
# 0 years        22
# Unknown        18
# 17 years       17
# 5 weeks        11
# 18 years       10
# 19 years        3
# 20 years        2
# Name: AgeuponOutcome, dtype: int64
# 26729
